# %% [markdown]
# # Text to SQL - Question generation and testing for the Hack Zurich

# %%
# !git clone https://github.com/statistikZH/statbot.git
# !git pull
# Out:
# Cloning into 'statbot'...
# remote: Enumerating objects: 1450, done.
# remote: Counting objects: 100% (777/777), done.
# remote: Compressing objects: 100% (435/435), done.
# remote: Total 1450 (delta 400), reused 693 (delta 331), pack-reused 673
# Receiving objects: 100% (1450/1450), 40.83 MiB | 11.85 MiB/s, done.
# Resolving deltas: 100% (709/709), done.
# Checking out files: 100% (466/466), done.

# %%
# %cd statbot/hackathon_hackzurich/
# !pwd
# Out:
# /content/statbot/hackathon_hackzurich
# /content/statbot/hackathon_hackzurich

# %%
# !pip install transformers[sentencepiece]
# Out:
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.10.3-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 15.0 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 66.7 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 57.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 90.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.62.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.0.12)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.8.1)
# Collecting sentencepiece==0.1.91
#   Downloading sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.4 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.17.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers[sentencepiece]) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers[sentencepiece]) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[sentencepiece]) (3.5.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers[sentencepiece]) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers, sentencepiece
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.17 pyyaml-5.4.1 sacremoses-0.0.45 sentencepiece-0.1.91 tokenizers-0.10.3 transformers-4.10.3

# %%
import os
import random
from typing import List, Tuple
import json

import pandas as pd
import sqlalchemy
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %% [markdown]
# If you plan to add views to generate questions, you should add rows to the csv file in input_data/INDICATORS_VIEW.csv. Do not fill all columns (indicator_id, a short description, question type (as 1), name of the view and column name of the view value).

# %%
NB_SAMPLES = 1 # number of samples per type (default: 1)

# %% [markdown]
# # Get Zurich and Basel data

# %%
# Data paths
INPUT_FOLDER = 'input_data'
INDICATORS_FILE = 'EN_INDICATORS.csv'
INDICATORS_VALUES_FILE = 'EN_INDICATOR_VALUES.csv'
INDICATORS_VIEWS_FILE = 'INDICATORS_VIEWS.csv'
SPATIALUNIT_FILE = 'EN_T_SPATIALUNIT.csv'

# %% [markdown]
# # Generation of natural language questions & SQL Statements
# Read in a dataset with indicator metadata and short descriptions which can be used to generate questions.

# %%
indicators = pd.read_csv(os.path.join(INPUT_FOLDER, INDICATORS_FILE))
indicators.columns = [c.lower() for c in indicators.columns]
indicators = indicators.rename(columns={"name": "indicator_name"})

# %%
descriptions = pd.read_csv(os.path.join(INPUT_FOLDER, INDICATORS_VIEWS_FILE))
indicators = indicators.merge(descriptions, on='indicator_id', how='left')

# %% [markdown]
# ### Create a single dataset with all information
#  Create a combined dataset containing all the information (values, indicator labels, spatial unit labels)  to make the generation of the question / sql pairs easier.

# %%
indicators_values = pd.read_csv(os.path.join(INPUT_FOLDER, INDICATORS_VALUES_FILE))
indicators_values.columns = [c.lower() for c in indicators_values.columns]
gp_data = indicators_values.merge(indicators, on='indicator_id', how='left')

# %%
spatial_units = pd.read_csv(os.path.join(INPUT_FOLDER, SPATIALUNIT_FILE))
spatial_units.columns = [c.lower() for c in spatial_units.columns]
spatial_units = spatial_units.rename(columns={'name': 'municipality_name'})

# %%
gp_data = gp_data.merge(spatial_units, on='spatialunit_id', how='left')

# %% [markdown]
# ### Create a dataset with random values, years and municipalities per indicator
#
#  To fill in the questions and queries, random values, years and municipalities are drawn for each indicator. These are then integrated into the templates dynamically.

# %%
spatial_units = spatial_units[['spatialunit_id', 'municipality_name']]
gp_data = gp_data[gp_data['type_id']==1]
gp_data = gp_data[gp_data['question_type']<=2]
grouping_columns = ['indicator_id', 'indicator_name', 'short_description', 'question_type']
grouped_samples = gp_data.groupby(by=grouping_columns)

sample_columns = grouping_columns + ['value', 'year', 'spatialunit_id', 'view_name', 'view_column_value']
samples = grouped_samples.sample(n=NB_SAMPLES).reset_index()[sample_columns]
samples = samples.merge(spatial_units, on='spatialunit_id', how='left')
samples
# Out:
#     indicator_id  ...         municipality_name
# 0            385  ...           Oberengstringen
# 1            386  ...                 Steinmaur
# 2            399  ...                Grueningen
# 3            401  ...                Fehraltorf
# 4            480  ...  Oberstammheim (bis 2018)
# 5            481  ...                Volketswil
# 6            601  ...                   Pfungen
# 7            606  ...                Duebendorf
# 8            607  ...                 Weiningen
# 9            611  ...                  Hedingen
# 10           612  ...            Affoltern a.A.
# 11           996  ...         Hirzel (bis 2017)
# 12           997  ...                  Daenikon
# 13           998  ...                 Boppelsen
# 14           999  ...                  Obfelden
#
# [15 rows x 10 columns]

# %%
def create_question_query(sample: pd.Series) -> Tuple[List[str], List[str]]:
    '''
    From a sample values, create 7 questions and 7 associated queries
    Args:
        - sample: row of random observations values
    Return:
        - questions: list of question generated with the values from sample
        - queries: : list of queries generated with the values from sample
    '''

    indicator, view, view_column, random_value, indicator_id, indicator_year, municipality = sample[
        ['short_description', 'view_name', 'view_column_value', 'value', 'indicator_id', 'year', 'municipality_name']
    ].values
    
    questions = [
        f"How high is the {indicator} in {municipality} in the year {indicator_year}?", # 0
        f"Which municipality has the highest {indicator}?", # 1
        f"Which municipality has the minimum {indicator}?", # 2
        f"What are the highest, lowest and average {indicator}?", # 3
        f"How many municipalities have a {indicator} higher than {random_value} per year?", # 4
        f"How high is the total {indicator} in the Canton Zurich in the year {indicator_year}?", # 5
        f"Which region had the lowest {indicator} in the year {indicator_year}?" # 6
    ]
    
    queries = [
        # 0
        f"SELECT T1.{view_column} \
        FROM {view} AS T1 \
        JOIN spatialunit AS T2 ON T1.spatialunit_id = T2.spatialunit_id \
        WHERE T2.name LIKE '{municipality}' AND T1.year = {indicator_year}", 
        
        # 1
        f"SELECT T2.name \
        FROM spatialunit AS T2 \
        JOIN {view} AS T1 ON T2.spatialunit_id = T1.spatialunit_id \
        ORDER BY T1.{view_column} DESC LIMIT 1",
        
        # 2
        f"SELECT T2.name \
        FROM spatialunit AS T2 \
        JOIN {view} AS T1 ON T2.spatialunit_id = T1.spatialunit_id \
        ORDER BY T1.{view_column} ASC LIMIT 1",
        
        # 3
        f"SELECT MAX(T1.{view_column}::numeric), \
        MIN(T1.{view_column}::numeric), AVG(T1.{view_column}::numeric) \
        FROM {view} AS T1",
        
        # 4
        f"SELECT T1.year, COUNT(*) \
        FROM {view} AS T1 \
        JOIN spatialunit AS T2 ON T1.spatialunit_id = T2.spatialunit_id \
        WHERE T1.{view_column}::numeric > {random_value} AND T2.type_id = 1 \
        GROUP BY T1.year",
        
        # 5
        f"SELECT T1.{view_column} FROM {view} AS T1 \
        JOIN spatialunit AS T2 ON T1.spatialunit_id = T2.spatialunit_id \
        WHERE T2.type_id = 8 AND T1.year = {indicator_year}",
        
        # 6
        f"SELECT T2.name \
        FROM {view} AS T1 \
        JOIN spatialunit AS T2 ON T1.spatialunit_id = T2.spatialunit_id \
        WHERE T2.type_id = 4 AND T1.year = {indicator_year} \
        ORDER BY T1.{view_column} \
        LIMIT 1"
    ]
    return questions, queries

# %%
all_questions, all_queries = [], []
for _, sample in samples.iterrows():   
    questions, queries = create_question_query(sample)
    all_questions.extend(questions)
    all_queries.extend(queries)

# %%
df = pd.DataFrame({'questions': all_questions, 'queries': all_queries})
df.to_csv("questions_queries_python.csv", index=False)

# %% [markdown]
# ## Test the SQL queries on Postgres
#
# Run this if you want to test the queries in postgres (you will need an up to date postgres database).e

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.23)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.7.4.3)

# %%
import psycopg2
import sqlalchemy

DB_USER = 'YOUR_DB_USER'
DB_PW = 'YOUR_PASSWORD'
DB_HOST = 'YOUR_DB_HOST'
DB_PORT = 'YOUR_DB_PORT'
DB_SCHEMA = 'YOUR_DB_SCHEMA'
DB = 'YOUR_DB'
DRIVERNAME = "postgresql"

engine = sqlalchemy.create_engine(
    sqlalchemy.engine.url.URL(
        drivername=DRIVERNAME,
        username=DB_USER,
        password=DB_PW,
        host=DB_HOST,
        port=DB_PORT,
        database=DB,
    ),
    echo_pool=True,
)
print("connecting with engine " + str(engine))
connection = engine.connect()
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SADeprecationWarning: Calling URL() directly is deprecated and will be disabled in a future release.  The public constructor for URL is now the URL.create() method.
# connecting with engine Engine(postgresql://postgres:***@database-1.cluster-cuqkxqloyykq.eu-central-1.rds.amazonaws.com:5432/hack_zurich)

# %%
df = pd.read_csv("questions_queries_python.csv")

# %%
def run_query(df: pd.DataFrame, query_number: int) -> None:
    '''
    Run a query on the database and prints the associted question and answer
    Args:
        - df: dataframe with all random samples
        - query_number: index of the row of (question, query) to select
    '''
    question = df['questions'].iloc[query_number]
    query = df['queries'].iloc[query_number]
    answer = connection.execute(query)
    
    print(f"Question {query_number}: {question}")
    print(f"Answer {query_number}: {[r for r in answer]}\n")

# %% [markdown]
# ### Run one query

# %%
run_query(df, query_number=6)
# Out:
# Question 6: Which region had the lowest share of people living in proximity of a busstop in the year 2013?
# Answer 6: [('Region Zimmerberg',)]

# %% [markdown]
# ### Run all queries

# %%
for i in range(len(df)):
    run_query(df, i)
    if i>20:
        break
# Out:
# Question 0: How high is the share of people living in proximity of a busstop in Oberengstringen in the year 2013?
# Answer 0: [('96.3',)]
#
# Question 1: Which municipality has the highest share of people living in proximity of a busstop?
# Answer 1: [('Faellanden',)]
#
# Question 2: Which municipality has the minimum share of people living in proximity of a busstop?
# Answer 2: [('Andelfingen',)]
#
# Question 3: What are the highest, lowest and average share of people living in proximity of a busstop?
# Answer 3: [(Decimal('99.6'), Decimal('0'), Decimal('54.4117080745341615'))]
#
# Question 4: How many municipalities have a share of people living in proximity of a busstop higher than 96.3 per year?
# Answer 4: [(2013, 3), (2003, 7), (2015, 3), (2008, 6), (2014, 3), (2010, 6), (2007, 5), (2002, 8), (2004, 6), (2006, 6), (2000, 6), (2011, 4), (2001, 7), (2012, 4), (2009, 5), (2005, 7)]
#
# Question 5: How high is the total share of people living in proximity of a busstop in the Canton Zurich in the year 2013?
# Answer 5: [('48.3',)]
#
# Question 6: Which region had the lowest share of people living in proximity of a busstop in the year 2013?
# Answer 6: [('Region Zimmerberg',)]
#
# Question 7: How high is the share of people living in proximity of a trainstation in Steinmaur in the year 2011?
# Answer 7: [('5.7',)]
#
# Question 8: Which municipality has the highest share of people living in proximity of a trainstation?
# Answer 8: [('Thalheim a.d.Th.',)]
#
# Question 9: Which municipality has the minimum share of people living in proximity of a trainstation?
# Answer 9: [('Freienstein-Teufen',)]
#
# Question 10: What are the highest, lowest and average share of people living in proximity of a trainstation?
# Answer 10: [(Decimal('85.2'), Decimal('0'), Decimal('6.2056211180124224'))]
#
# Question 11: How many municipalities have a share of people living in proximity of a trainstation higher than 5.7 per year?
# Answer 11: [(2013, 42), (2003, 49), (2008, 47), (2015, 40), (2010, 41), (2014, 43), (2007, 46), (2002, 48), (2004, 46), (2006, 43), (2000, 47), (2011, 42), (2001, 51), (2012, 41), (2009, 45), (2005, 44)]
#
# Question 12: How high is the total share of people living in proximity of a trainstation in the Canton Zurich in the year 2011?
# Answer 12: [('3.5',)]
#
# Question 13: Which region had the lowest share of people living in proximity of a trainstation in the year 2011?
# Answer 13: [('Region Zuerich',)]
#
# Question 14: How high is the number of cars per capita in Grueningen in the year 2011?
# Answer 14: [('630.6',)]
#
# Question 15: Which municipality has the highest number of cars per capita?
# Answer 15: [('Dielsdorf',)]
#
# Question 16: Which municipality has the minimum number of cars per capita?
# Answer 16: [('Rickenbach',)]
#
# Question 17: What are the highest, lowest and average number of cars per capita?
# Answer 17: [(Decimal('805.1'), Decimal('182.8'), Decimal('563.4521439915299100'))]
#
# Question 18: How many municipalities have a number of cars per capita higher than 630.6 per year?
# Answer 18: [(2013, 31), (2003, 10), (2015, 36), (2008, 16), (2010, 18), (2014, 33), (2007, 16), (2019, 30), (2002, 12), (2004, 16), (2006, 19), (2020, 33), (2011, 21), (2017, 35), (2016, 37), (2012, 29), (2018, 33), (2009, 15), (2005, 11)]
#
# Question 19: How high is the total number of cars per capita in the Canton Zurich in the year 2011?
# Answer 19: [('482.7',)]
#
# Question 20: Which region had the lowest number of cars per capita in the year 2011?
# Answer 20: [('Region Zuerich',)]
#
# Question 21: How high is the share of people living in proximity of a trainstation or busstop in Fehraltorf in the year 2003?
# Answer 21: [('71',)]

# %% [markdown]
# ## Generate paraphrases
#
# ML-Model taken from:
# * https://github.com/Vamsi995/Paraphrase-Generator
# * https://huggingface.co/Vamsi/T5_Paraphrase_Paws

# %%
df = pd.read_csv("questions_queries_python.csv")
tokenizer = AutoTokenizer.from_pretrained("Vamsi/T5_Paraphrase_Paws" , use_fast=False)
model = AutoModelForSeq2SeqLM.from_pretrained("Vamsi/T5_Paraphrase_Paws")
# Out:
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
def generate_paraphrases(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Script for creating paraphrases and thus expanding the q&a pairs generated through the first script
    At the time of writing it generates from 90 initial q&a pairs, around 

    ML-Model taken from https://github.com/Vamsi995/Paraphrase-Generator
    https://huggingface.co/Vamsi/T5_Paraphrase_Paws

    Version 0.1.1 - 15.09.2021
    Christian Ruiz - Statistisches Amt Kanton Zürich
    CC0
    
    History 
    Version 0.1.2 -15.09.2021 - Umlaut-corrections for the SQL-queries
    Version 0.1.1 -15.09.2021 - First version public
    '''
    output_df = df

    for i in range(len(df)):
        sentence=df['questions'].iloc[i]
        print(i, " ", sentence)
        text =  "paraphrase: " + sentence + " </s>"

        encoding = tokenizer.encode_plus(text, pad_to_max_length=True, return_tensors="pt")
        input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]

        outputs = model.generate(
            input_ids=input_ids, attention_mask=attention_masks,
            max_length=256,
            do_sample=True,
            top_k=120,
            top_p=0.95,
            early_stopping=True,
            num_return_sequences=8
        )

        for output in outputs:
            line = tokenizer.decode(output, skip_special_tokens=True, clean_up_tokenization_spaces=True)
            output_df = output_df.append({'questions': line, 'queries': df['queries'].iloc[i]}, ignore_index=True)
    
    return output_df

# %%
output_df = generate_paraphrases(df)
# Out:
# 0   How high is the share of people living in proximity of a busstop in Oberengstringen in the year 2013?
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2204: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:191: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# 1   Which municipality has the highest share of people living in proximity of a busstop?
# 2   Which municipality has the minimum share of people living in proximity of a busstop?
# 3   What are the highest, lowest and average share of people living in proximity of a busstop?
# 4   How many municipalities have a share of people living in proximity of a busstop higher than 96.3 per year?
# 5   How high is the total share of people living in proximity of a busstop in the Canton Zurich in the year 2013?
# 6   Which region had the lowest share of people living in proximity of a busstop in the year 2013?
# 7   How high is the share of people living in proximity of a trainstation in Steinmaur in the year 2011?
# 8   Which municipality has the highest share of people living in proximity of a trainstation?
# 9   Which municipality has the minimum share of people living in proximity of a trainstation?
# 10   What are the highest, lowest and average share of people living in proximity of a trainstation?
# 11   How many municipalities have a share of people living in proximity of a trainstation higher than 5.7 per year?
# 12   How high is the total share of people living in proximity of a trainstation in the Canton Zurich in the year 2011?
# 13   Which region had the lowest share of people living in proximity of a trainstation in the year 2011?
# 14   How high is the number of cars per capita in Grueningen in the year 2011?
# 15   Which municipality has the highest number of cars per capita?
# 16   Which municipality has the minimum number of cars per capita?
# 17   What are the highest, lowest and average number of cars per capita?
# 18   How many municipalities have a number of cars per capita higher than 630.6 per year?
# 19   How high is the total number of cars per capita in the Canton Zurich in the year 2011?
# 20   Which region had the lowest number of cars per capita in the year 2011?
# 21   How high is the share of people living in proximity of a trainstation or busstop in Fehraltorf in the year 2003?
# 22   Which municipality has the highest share of people living in proximity of a trainstation or busstop?
# 23   Which municipality has the minimum share of people living in proximity of a trainstation or busstop?
# 24   What are the highest, lowest and average share of people living in proximity of a trainstation or busstop?
# 25   How many municipalities have a share of people living in proximity of a trainstation or busstop higher than 71.0 per year?
# 26   How high is the total share of people living in proximity of a trainstation or busstop in the Canton Zurich in the year 2003?
# 27   Which region had the lowest share of people living in proximity of a trainstation or busstop in the year 2003?
# 28   How high is the share of public transport in traffic movements of people living in Oberstammheim (bis 2018) in the year 2016?
# 29   Which municipality has the highest share of public transport in traffic movements of people living?
# 30   Which municipality has the minimum share of public transport in traffic movements of people living?
# 31   What are the highest, lowest and average share of public transport in traffic movements of people living?
# 32   How many municipalities have a share of public transport in traffic movements of people living higher than 9.0 per year?
# 33   How high is the total share of public transport in traffic movements of people living in the Canton Zurich in the year 2016?
# 34   Which region had the lowest share of public transport in traffic movements of people living in the year 2016?
# 35   How high is the share of motorised private transport in traffic movements of people living in Volketswil in the year 2013?
# 36   Which municipality has the highest share of motorised private transport in traffic movements of people living?
# 37   Which municipality has the minimum share of motorised private transport in traffic movements of people living?
# 38   What are the highest, lowest and average share of motorised private transport in traffic movements of people living?
# 39   How many municipalities have a share of motorised private transport in traffic movements of people living higher than 91.0 per year?
# 40   How high is the total share of motorised private transport in traffic movements of people living in the Canton Zurich in the year 2013?
# 41   Which region had the lowest share of motorised private transport in traffic movements of people living in the year 2013?
# 42   How high is the number of newly registered cars in Pfungen in the year 2006?
# 43   Which municipality has the highest number of newly registered cars?
# 44   Which municipality has the minimum number of newly registered cars?
# 45   What are the highest, lowest and average number of newly registered cars?
# 46   How many municipalities have a number of newly registered cars higher than 25.4 per year?
# 47   How high is the total number of newly registered cars in the Canton Zurich in the year 2006?
# 48   Which region had the lowest number of newly registered cars in the year 2006?
# 49   How high is the share of hybrid vehicles in Duebendorf in the year 2015?
# 50   Which municipality has the highest share of hybrid vehicles?
# 51   Which municipality has the minimum share of hybrid vehicles?
# 52   What are the highest, lowest and average share of hybrid vehicles?
# 53   How many municipalities have a share of hybrid vehicles higher than 1.3 per year?
# 54   How high is the total share of hybrid vehicles in the Canton Zurich in the year 2015?
# 55   Which region had the lowest share of hybrid vehicles in the year 2015?
# 56   How high is the share of electric vehicles in Weiningen in the year 2011?
# 57   Which municipality has the highest share of electric vehicles?
# 58   Which municipality has the minimum share of electric vehicles?
# 59   What are the highest, lowest and average share of electric vehicles?
# 60   How many municipalities have a share of electric vehicles higher than 0.0 per year?
# 61   How high is the total share of electric vehicles in the Canton Zurich in the year 2011?
# 62   Which region had the lowest share of electric vehicles in the year 2011?
# 63   How high is the share of hybrid vehicles within the newly registered cars in Hedingen in the year 2020?
# 64   Which municipality has the highest share of hybrid vehicles within the newly registered cars?
# 65   Which municipality has the minimum share of hybrid vehicles within the newly registered cars?
# 66   What are the highest, lowest and average share of hybrid vehicles within the newly registered cars?
# 67   How many municipalities have a share of hybrid vehicles within the newly registered cars higher than 14.5 per year?
# 68   How high is the total share of hybrid vehicles within the newly registered cars in the Canton Zurich in the year 2020?
# 69   Which region had the lowest share of hybrid vehicles within the newly registered cars in the year 2020?
# 70   How high is the share of electric vehicles within the newly registered cars in Affoltern a.A. in the year 2013?
# 71   Which municipality has the highest share of electric vehicles within the newly registered cars?
# 72   Which municipality has the minimum share of electric vehicles within the newly registered cars?
# 73   What are the highest, lowest and average share of electric vehicles within the newly registered cars?
# 74   How many municipalities have a share of electric vehicles within the newly registered cars higher than 0.0 per year?
# 75   How high is the total share of electric vehicles within the newly registered cars in the Canton Zurich in the year 2013?
# 76   Which region had the lowest share of electric vehicles within the newly registered cars in the year 2013?
# 77   How high is the  Total new registrations of electric and hybrid motor cars [%]  in Hirzel (bis 2017) in the year 2014?
# 78   Which municipality has the highest  Total new registrations of electric and hybrid motor cars [%] ?
# 79   Which municipality has the minimum  Total new registrations of electric and hybrid motor cars [%] ?
# 80   What are the highest, lowest and average  Total new registrations of electric and hybrid motor cars [%] ?
# 81   How many municipalities have a  Total new registrations of electric and hybrid motor cars [%]  higher than 1.5 per year?
# 82   How high is the total  Total new registrations of electric and hybrid motor cars [%]  in the Canton Zurich in the year 2014?
# 83   Which region had the lowest  Total new registrations of electric and hybrid motor cars [%]  in the year 2014?
# 84   How high is the Total of electric and hybrid motor cars stock [%] in Daenikon in the year 2003?
# 85   Which municipality has the highest Total of electric and hybrid motor cars stock [%]?
# 86   Which municipality has the minimum Total of electric and hybrid motor cars stock [%]?
# 87   What are the highest, lowest and average Total of electric and hybrid motor cars stock [%]?
# 88   How many municipalities have a Total of electric and hybrid motor cars stock [%] higher than 0.2 per year?
# 89   How high is the total Total of electric and hybrid motor cars stock [%] in the Canton Zurich in the year 2003?
# 90   Which region had the lowest Total of electric and hybrid motor cars stock [%] in the year 2003?
# 91   How high is the Charging stations of electronic cars per 1000 inhabitants [no.]  in Boppelsen in the year 2021?
# 92   Which municipality has the highest Charging stations of electronic cars per 1000 inhabitants [no.] ?
# 93   Which municipality has the minimum Charging stations of electronic cars per 1000 inhabitants [no.] ?
# 94   What are the highest, lowest and average Charging stations of electronic cars per 1000 inhabitants [no.] ?
# 95   How many municipalities have a Charging stations of electronic cars per 1000 inhabitants [no.]  higher than 1.08028480235699 per year?
# 96   How high is the total Charging stations of electronic cars per 1000 inhabitants [no.]  in the Canton Zurich in the year 2021?
# 97   Which region had the lowest Charging stations of electronic cars per 1000 inhabitants [no.]  in the year 2021?
# 98   How high is the Charging stations of electronic cars [no.]  in Obfelden in the year 2021?
# 99   Which municipality has the highest Charging stations of electronic cars [no.] ?
# 100   Which municipality has the minimum Charging stations of electronic cars [no.] ?
# 101   What are the highest, lowest and average Charging stations of electronic cars [no.] ?
# 102   How many municipalities have a Charging stations of electronic cars [no.]  higher than 10.0 per year?
# 103   How high is the total Charging stations of electronic cars [no.]  in the Canton Zurich in the year 2021?

# %%
# Adjustments
output_df = output_df[['questions','queries']]
output_df['questions'] = output_df['questions'].str.lower()
output_df = output_df.drop_duplicates()

# Replace the Umlaut in the SQL-queries for ValueNet
output_df['queries'] = output_df['queries'].str.replace("ü", "ue")
output_df['queries'] = output_df['queries'].str.replace("ä", "ae")
output_df['queries'] = output_df['queries'].str.replace("ö", "oe")

# Save paraphrases
output_df.to_csv("questions_queries_paraphrases.csv", index=False)

# %% [markdown]
# ## Convert to valunet preprocessing format
#
# Valuenet errors when tokenising the SQL with ::numeric, hence we remove it here. If you query a PostgreSQL database again with these queries, be mindful that you might need the ::numeric.

# %%
df = pd.read_csv("questions_queries_paraphrases.csv")

# %%
def df_to_spider_format(df: pd.DataFrame) -> list:
    handmade_data = []
    
    for _, row in df.iterrows():
        query = row['queries'].replace('::numeric', '')
        row_dict = {
            'db_id': 'hack_zurich',
            'query': query,
            'question': row['questions']
        }
        handmade_data.append(row_dict)
    return handmade_data

# %%
handmade_data = df_to_spider_format(df)

# %% [markdown]
# ## Save question_queries in the format required by valuenet

# %%
TRAIN_RATIO = 0.8
training_samples = int(len(handmade_data)*TRAIN_RATIO)
train_data = handmade_data[:training_samples]
dev_data = handmade_data[training_samples:]

with open('handmade_data_train.json', 'w') as outfile:
    json.dump(train_data, outfile)

with open('handmade_data_dev.json', 'w') as outfile:
    json.dump(dev_data, outfile)

len(train_data), len(dev_data)

# %% [markdown]
# ## Preprocessing
#
# If you plan to train Valuenet with this data, you can follow the steps explained in [preprocess_custom_data-01.ipynb](https://github.com/hack-with-admin-ch/aws-sagemaker-notebook-valuenet/blob/training_options/preprocess_custom_data-01.ipynb).
